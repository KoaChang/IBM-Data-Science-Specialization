# %%
# this project analyzes the McDonalds menu nutritional info to make some cool insights

# %%
import pandas as pd

df = pd.read_csv('menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
def calc_ratio(row):
    calories = row['Calories']
    protein = row['Protein']
    
    if calories == 0 or protein == 0:
        return 0
    else:
        return protein/calories

# %%
df['Protein_To_Calorie_Ratio'] = df.apply(calc_ratio,axis=1)
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
top10 = df.nlargest(10,'Protein_To_Calorie_Ratio')
# Out:
#            Category                                              Item  \
# 86           Salads    Premium Bacon Ranch Salad with Grilled Chicken
# 163    Coffee & Tea                              Nonfat Latte (Small)
# 165    Coffee & Tea                              Nonfat Latte (Large)
# 89           Salads      Premium Southwest Salad with Grilled Chicken
# 164    Coffee & Tea                             Nonfat Latte (Medium)
# 58   Chicken & Fish          Premium Grilled Chicken Classic Sandwich
# 62   Chicken & Fish        Premium Grilled Chicken Ranch BLT Sandwich
# 130       Beverages                               1% Low Fat Milk Jug
# 60   Chicken & Fish             Premium Grilled Chicken Club Sandwich
# 71   Chicken & Fish  Premium McWrap Chicken & Bacon (Grilled Chicken)
#
#           Serving Size  Calories  Calories from Fat  Total Fat  \
# 86      8.5 oz (241 g)       220                 80        8.0
# 163       12 fl oz cup       100                  0        0.0
# ...

# %%
top10_items = top10['Item']
top10_items
# Out:
# 86       Premium Bacon Ranch Salad with Grilled Chicken
# 163                                Nonfat Latte (Small)
# 165                                Nonfat Latte (Large)
# 89         Premium Southwest Salad with Grilled Chicken
# 164                               Nonfat Latte (Medium)
# 58             Premium Grilled Chicken Classic Sandwich
# 62           Premium Grilled Chicken Ranch BLT Sandwich
# 130                                 1% Low Fat Milk Jug
# 60                Premium Grilled Chicken Club Sandwich
# 71     Premium McWrap Chicken & Bacon (Grilled Chicken)
# Name: Item, dtype: object
